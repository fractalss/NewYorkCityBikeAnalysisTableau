# %% [markdown]
# # City Bike Data
# ## Time span : May 2018 - May 2019

# %%
import pandas as pd

# %%
files = !ls *.csv #For Ipython only
files
# Out:
# ['JC-201805-citibike-tripdata.csv',
#  'JC-201806-citibike-tripdata.csv',
#  'JC-201807-citibike-tripdata.csv',
#  'JC-201808-citibike-tripdata.csv',
#  'JC-201809-citibike-tripdata.csv',
#  'JC-201810-citibike-tripdata.csv',
#  'JC-201811-citibike-tripdata.csv',
#  'JC-201812-citibike-tripdata.csv',
#  'JC-201901-citibike-tripdata.csv',
#  'JC-201902-citibike-tripdata.csv',
#  'JC-201903-citibike-tripdata.csv',
#  'JC-201904-citibike-tripdata.csv',
#  'JC-201905-citibike-tripdata.csv']

# %%
df = pd.concat([pd.read_csv(f, header=None,low_memory=False) for f in files], keys=files)

# %%
df.head()
# Out:
#                                              0                         1   \
# JC-201805-citibike-tripdata.csv 0  tripduration                 starttime
#                                 1           131  2018-05-01 07:29:57.5490
#                                 2            73  2018-05-01 08:13:58.2560
#                                 3          4929  2018-05-01 08:17:21.3110
#                                 4           432  2018-05-01 08:25:58.7150
#
#                                                          2                 3   \
# JC-201805-citibike-tripdata.csv 0                  stoptime  start station id
#                                 1  2018-05-01 07:32:08.6160              3183
#                                 2  2018-05-01 08:15:11.9230              3183
#                                 3  2018-05-01 09:39:31.0770              3183
#                                 4  2018-05-01 08:33:10.8960              3183
#
# ...

# %%
df.to_csv("bike_data_past_year.csv")
